# %% [markdown]
# # Introdução à Análise de Dados com Python e Pandas
# ## Pandas
# É uma biblioteca licenciada com código aberto que oferece estruturas de dados de alto desempenho e de fácil utilização voltado a análise de dados para a linguagem de programação Python. É amplamente utilizado para a preparação e visualização de dados e tem sido fundamental para impulsionar a utilização de Python na comunidade científica de dados.
# ## Estrutura de dados
# Para trabalhar com Pandas, o usuário deve estar familiarizado com duas estruturas de dados que são:
# #### Series:
# A estrutura Serie, é um array unidimensional, semelhante a uma lista em Python, porém criado sobre o numpy. Além da velocidade de processamento, a principal característica que o difere de uma lista comum é que seus índices podem ser mutáveis, dependendo da necessidade do programa.
# #### Dataframe
# um Dataframe representa uma estrutura de dados tabular, semelhante a uma planilha, contendo uma coleção de colunas ordenadas, cada uma das quais pode ser um tipo de valor diferente (numérico, string, booleano, etc.)

# %% [markdown]
# ### Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib as plot
import sys
# %matplotlib inline

# %% [markdown]
# ### Versões das bibliotecas

# %%
print('Versão Python: ' + sys.version)
print('Versão Pandas: ' + pd.__version__)
print('Versão Matplotlib: ' + plot.__version__)
# Out:
# Versão Python: 3.6.2 |Continuum Analytics, Inc.| (default, Jul 20 2017, 13:14:59)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]
# Versão Pandas: 0.20.3
# Versão Matplotlib: 2.0.2

# %% [markdown]
# ### Criação de uma Serie

# %%
s = pd.Series([100,200,300,400,np.nan]) 
s
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3    400.0
# 4      NaN
# dtype: float64

# %% [markdown]
# ### Alterando índices

# %%
s.index =['A','B','C','D','E']
s
# Out:
# A    100.0
# B    200.0
# C    300.0
# D    400.0
# E      NaN
# dtype: float64

# %% [markdown]
# ### Criação de um dataframe

# %%
estados = {
    'estado': ['Bahia','Ceará','Pernambuco','Maranhão', 'Alagoas', 'Rio Grande do Norte','Piauí','Paraíba','Sergipe'],
    'capital': ['Salvador','Fortaleza', 'Recife', 'São Luís', 'Maceió','Natal','Teresina','João Pessoa', 'Aracaju'],
    'sigla': ['BA','CE','PE','MA','AL','RN','PI','PB','SE'],
    'populacao':[2921087,2591188,1617183,1073893,1013773,869954,844245,791438,632744]
}
nordeste = pd.DataFrame(estados,columns=['estado','capital','sigla','populacao'])
nordeste
# Out:
#                 estado      capital sigla  populacao
# 0                Bahia     Salvador    BA    2921087
# 1                Ceará    Fortaleza    CE    2591188
# 2           Pernambuco       Recife    PE    1617183
# 3             Maranhão     São Luís    MA    1073893
# 4              Alagoas       Maceió    AL    1013773
# 5  Rio Grande do Norte        Natal    RN     869954
# 6                Piauí     Teresina    PI     844245
# 7              Paraíba  João Pessoa    PB     791438
# 8              Sergipe      Aracaju    SE     632744

# %% [markdown]
# ### Verificando as colunas existentes

# %%
nordeste.columns
# Out:
# Index(['estado', 'capital', 'sigla', 'populacao'], dtype='object')

# %% [markdown]
# ### Verificando primeiros registros

# %%
nordeste.head(7)
# Out:
#                 estado    capital sigla  populacao
# 0                Bahia   Salvador    BA    2921087
# 1                Ceará  Fortaleza    CE    2591188
# 2           Pernambuco     Recife    PE    1617183
# 3             Maranhão   São Luís    MA    1073893
# 4              Alagoas     Maceió    AL    1013773
# 5  Rio Grande do Norte      Natal    RN     869954
# 6                Piauí   Teresina    PI     844245

# %% [markdown]
# ### Verificando últimos registros

# %%
nordeste.tail(4)
# Out:
#                 estado      capital sigla  populacao
# 5  Rio Grande do Norte        Natal    RN     869954
# 6                Piauí     Teresina    PI     844245
# 7              Paraíba  João Pessoa    PB     791438
# 8              Sergipe      Aracaju    SE     632744

# %% [markdown]
# ### Verificando valores únicos

# %%
#nordeste['sigla'].unique()
len(nordeste) == len(nordeste['sigla'].unique())
# Out:
# True

# %% [markdown]
# ### Alterando índices

# %%
nordeste.index = nordeste['sigla']
nordeste
# Out:
#                     estado      capital sigla  populacao
# sigla
# BA                   Bahia     Salvador    BA    2921087
# CE                   Ceará    Fortaleza    CE    2591188
# PE              Pernambuco       Recife    PE    1617183
# MA                Maranhão     São Luís    MA    1073893
# AL                 Alagoas       Maceió    AL    1013773
# RN     Rio Grande do Norte        Natal    RN     869954
# PI                   Piauí     Teresina    PI     844245
# PB                 Paraíba  João Pessoa    PB     791438
# SE                 Sergipe      Aracaju    SE     632744

# %% [markdown]
# ### Apagando colunas duplicadas

# %%
del nordeste['sigla']
nordeste
# Out:
#                     estado      capital  populacao
# sigla
# BA                   Bahia     Salvador    2921087
# CE                   Ceará    Fortaleza    2591188
# PE              Pernambuco       Recife    1617183
# MA                Maranhão     São Luís    1073893
# AL                 Alagoas       Maceió    1013773
# RN     Rio Grande do Norte        Natal     869954
# PI                   Piauí     Teresina     844245
# PB                 Paraíba  João Pessoa     791438
# SE                 Sergipe      Aracaju     632744

# %% [markdown]
# ### Carregando dados externos
#
# Geralmente é mais comum a necessidade de fazer a leitura de uma base de dados externa para um Dataframe, o Pandas oferece alguns métodos para esse fim e serão descritos a seguir:
#
# • CSV
#
# • EXCEL
#
# • Clipboard
#
# • db.py
#
# • pydataset
#
# • URL

# %% [markdown]
# ### CSV
# Ler um arquivo CSV é simples, basta chamar a função read_csv. Por padrão, a função read_csv espera um delimitador que pode ser uma virgula, mas pode-se alterar usando o parâmetro sep.

# %%
# !ls
to_csv = pd.read_csv('iris.csv', header=None, names=['SepalLengthCm', 'SepalWidthCm', 
                                                     'PetalLengthCm','PetalWidthCm','Species'])
#to_csv['Species'].unique()
to_csv.describe()
# Out:
# Agrupamento.ipynb      Teste DB.ipynb         group.png
# ENUCOMP.ipynb          copacabana_lat_lng.csv iris.csv
# Junção.ipynb           database.sqlite        primary-results.csv
# Plotar Mapa.ipynb      futebol.xlsx
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ### Excel
# Pandas permite leitura e escrita no formato Excel. Ler a partir de arquivos Excel requer a biblioteca xlrd, pode-se instalar via pip (pip install xlrd).

# %%
to_excel = pd.read_excel('futebol.xlsx', 'Sheet1')
to_excel
# Out:
#     ano      time  vitorias  derrotas
# 0  2010  Flamengo        11         5
# 1  2011  Flamengo         8         8
# 2  2012  Flamengo        10         6
# 3  2011     Vasco        15         1
# 4  2012     Vasco        11         5
# 5  2010  Cruzeiro         6        10
# 6  2011  Cruzeiro        10         6
# 7  2012  Cruzeiro         4        12

# %% [markdown]
# ### Clipboard
#
# Enquanto os resultados de uma query podem ser convertidos para um DataFrame, outra opção é copiar os resultados diretamente do clipboard. Você tem uma página web com dados delimitados, então você pode copiar para seu clipboard e colar direto no seu DataFrame. A função realiza um bom trabalho identificando qual é o delimitador, mas você pode usar o parâmetro sep para ser explicito.

# %%
to_clipboard = pd.read_clipboard()
to_clipboard
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-14-7966f27ed273> in <module>()
# ----> 1 to_clipboard = pd.read_clipboard()
#       2 to_clipboard
#
# ~/miniconda3/envs/SNCTTIMON/lib/python3.6/site-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      61         sep = '\s+'
#      62
# ---> 63     return read_table(StringIO(text), sep=sep, **kwargs)
#      64
#      65
#
# ...

# %% [markdown]
# ### db.py
# É uma maneira mais fácil de interagir com bancos de dados. Facilita a pes- quisa de tabelas, colunas, visualizações, etc. Ele coloca a ênfase na interação do usuário, na exibição de informações e no fornecimento de funções auxiliares fáceis de usar. Suporta PostgreSQL, MySQL, SQLite, Redshift, MS SQL Server e Oracle.

# %%
from db import DB
to_db = DB(filename='database.sqlite' , dbtype='sqlite')
to_db.tables
df = to_db.tables.Iris.all()
df.head()
# Out:
# Indexing schema. This will take a second...finished!
# Refreshing schema. Please wait...done!
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### pydataset
# Fornece acesso instantâneo a muitos conjuntos de dados diretamente do Python, a versão atual conta com 757 datasets prontos para serem importados e utilizados juntamente com o Pandas.

# %%
import pydataset
pydataset.data()
# Out:
#                 dataset_id  \
# 0            AirPassengers
# 1                  BJsales
# 2                      BOD
# 3             Formaldehyde
# 4             HairEyeColor
# 5             InsectSprays
# 6           JohnsonJohnson
# 7                LakeHuron
# 8         LifeCycleSavings
# 9                     Nile
# 10           OrchardSprays
# 11             PlantGrowth
# 12               Puromycin
# 13                 Titanic
# 14             ToothGrowth
# 15           UCBAdmissions
# 16          UKDriverDeaths
# 17                   UKgas
# 18             USAccDeaths
# 19               USArrests
# 20          USJudgeRatings
# 21   USPersonalExpenditure
# 22                VADeaths
# 23                WWWusage
# 24             WorldPhones
# 25                airmiles
# 26              airquality
# 27                anscombe
# 28                  attenu
# 29                attitude
# 30                 austres
# 31                    cars
# 32                chickwts
# ...

# %%
titanic = pydataset.data('titanic')
titanic.head()
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes
# 3  1st class  adults  man      yes
# 4  1st class  adults  man      yes
# 5  1st class  adults  man      yes

# %%
titanic.groupby(['class'])['survived'].value_counts()
# Out:
# class      survived
# 1st class  yes         203
#            no          122
# 2nd class  no          167
#            yes         118
# 3rd class  no          528
#            yes         178
# Name: survived, dtype: int64

# %% [markdown]
# ### URL
# Pode-se usar a biblioteca StringIO de Python para ler diretamente dados de uma URL. StringIO permite tratar uma string como um objeto do tipo arquivo.

# %%
import io
import requests
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
r=requests.get(url).content
to_url=pd.read_csv(io.StringIO(r.decode('utf-8')))
to_url
# Out:
#                               Country         Region
# 0                             Algeria         AFRICA
# 1                              Angola         AFRICA
# 2                               Benin         AFRICA
# 3                            Botswana         AFRICA
# 4                             Burkina         AFRICA
# 5                             Burundi         AFRICA
# 6                            Cameroon         AFRICA
# 7                          Cape Verde         AFRICA
# 8            Central African Republic         AFRICA
# 9                                Chad         AFRICA
# 10                            Comoros         AFRICA
# 11                              Congo         AFRICA
# 12      Congo, Democratic Republic of         AFRICA
# 13                           Djibouti         AFRICA
# 14                              Egypt         AFRICA
# 15                  Equatorial Guinea         AFRICA
# 16                            Eritrea         AFRICA
# ...

# %% [markdown]
# ### Filtros em Dataframes
# Existem vários métodos para selecionar dados em um Dataframe. Quando se manipula grande quantidade de dados a escolha do método influencia bastante, visto que alguns métodos são mais eficientes que outros. [Pandas Library 2017] destaca os seguintes métodos:
#
# • Filtro booleano: É possível filtrar qualquer coluna a partir de uma comparação relacional, por exemplo: pode-se recuperar apenas as capitais que tenham população acima de 1 milhão;
#
# • Método loc: É utilizado para seleção através de índices rotulados, mas também aceita uma matriz booleana;
#
# • Método iloc:É utilizado para seleção através deíndices inteiros,mas também aceita uma matriz booleana;
#
# • Método ix: Pode decidir indexar posicionalmente ou através de etiquetas dependendo do tipo de dados do índice. Está em desuso desde a versão Pandas 0.20.0.

# %% [markdown]
# ### Filtro booleano

# %%
nordeste
# Out:
#                     estado      capital  populacao
# sigla
# BA                   Bahia     Salvador    2921087
# CE                   Ceará    Fortaleza    2591188
# PE              Pernambuco       Recife    1617183
# MA                Maranhão     São Luís    1073893
# AL                 Alagoas       Maceió    1013773
# RN     Rio Grande do Norte        Natal     869954
# PI                   Piauí     Teresina     844245
# PB                 Paraíba  João Pessoa     791438
# SE                 Sergipe      Aracaju     632744

# %%
nordeste['populacao'] > 1000000
# Out:
# sigla
# BA     True
# CE     True
# PE     True
# MA     True
# AL     True
# RN    False
# PI    False
# PB    False
# SE    False
# Name: populacao, dtype: bool

# %% [markdown]
# ### Método loc

# %%
estados = {
    'estado': ['Bahia','Ceará','Pernambuco','Maranhão', 'Alagoas', 'Rio Grande do Norte','Piauí','Paraíba','Sergipe'],
    'capital': ['Salvador','Fortaleza', 'Recife', 'São Luís', 'Maceió','Natal','Teresina','João Pessoa', 'Aracaju'],
    'sigla': ['BA','CE','PE','MA','AL','RN','PI','PB','SE'],
    'populacao':[2921087,2591188,1617183,1073893,1013773,869954,844245,791438,632744]
}
nordeste = pd.DataFrame(estados,columns=['estado','capital','sigla','populacao'])
nordeste
# Out:
#                 estado      capital sigla  populacao
# 0                Bahia     Salvador    BA    2921087
# 1                Ceará    Fortaleza    CE    2591188
# 2           Pernambuco       Recife    PE    1617183
# 3             Maranhão     São Luís    MA    1073893
# 4              Alagoas       Maceió    AL    1013773
# 5  Rio Grande do Norte        Natal    RN     869954
# 6                Piauí     Teresina    PI     844245
# 7              Paraíba  João Pessoa    PB     791438
# 8              Sergipe      Aracaju    SE     632744

# %%
#nordeste.loc['CE']
nordeste.loc[nordeste['populacao'] < 1000000]
# Out:
#                 estado      capital sigla  populacao
# 5  Rio Grande do Norte        Natal    RN     869954
# 6                Piauí     Teresina    PI     844245
# 7              Paraíba  João Pessoa    PB     791438
# 8              Sergipe      Aracaju    SE     632744

# %% [markdown]
# ### Método iloc

# %%
nordeste.iloc[0]
# Out:
# estado          Bahia
# capital      Salvador
# sigla              BA
# populacao     2921087
# Name: 0, dtype: object

# %% [markdown]
# ### Método ix

# %%
nordeste.ix[4]
# Out:
# /Users/abilio/miniconda3/envs/SNCTTIMON/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# estado       Alagoas
# capital       Maceió
# sigla             AL
# populacao    1013773
# Name: 4, dtype: object

# %% [markdown]
# ### Limpeza de dados perdidos
# O problema de dados perdidos é de grande relevância para a análise de dados, pois deve- se tomar uma decisão importante para não prejudicar as estatísticas das colunas. O Pandas possui funções interessantes para tratar o problema de dados perdidos, as principais funções são:
#
# • isnull: Retorna objeto booleano indicando quais valores são nan;
#
# • notnull: Negação de isnull.
#
# • dropna: Utilizado para excluir linhas ou colunas que possuam dados perdidos;
#
# • fillna: Utilizado para preencher dados perdidos com base em critérios. Exemplo: Em uma coluna de idade de um Dataframe pode-se utilizar essa função para onde tiver dado perdido substituir pela média das idades da coluna;

# %% [markdown]
# ### isnull

# %%
s
# Out:
# A    100.0
# B    200.0
# C    300.0
# D    400.0
# E      NaN
# dtype: float64

# %%
s.describe()
# Out:
# count      4.000000
# mean     250.000000
# std      129.099445
# min      100.000000
# 25%      175.000000
# 50%      250.000000
# 75%      325.000000
# max      400.000000
# dtype: float64

# %%
s.isnull()
# Out:
# A    False
# B    False
# C    False
# D    False
# E     True
# dtype: bool

# %% [markdown]
# ### notnull

# %%
s.notnull()
# Out:
# A     True
# B     True
# C     True
# D     True
# E    False
# dtype: bool

# %% [markdown]
# ### dropna

# %%
s.dropna(inplace=True)
s
# Out:
# A    100.0
# B    200.0
# C    300.0
# D    400.0
# dtype: float64

# %% [markdown]
# ### fillna

# %%
s = pd.Series([100,200,300,400,np.nan]) 
s
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3    400.0
# 4      NaN
# dtype: float64

# %%
s.fillna(np.mean(s), inplace=True)

# %%
s
# Out:
# 0    100.0
# 1    200.0
# 2    300.0
# 3    400.0
# 4    250.0
# dtype: float64

# %%
s.describe()
# Out:
# count      5.000000
# mean     250.000000
# std      111.803399
# min      100.000000
# 25%      200.000000
# 50%      250.000000
# 75%      300.000000
# max      400.000000
# dtype: float64

# %% [markdown]
# ### Tratando dados perdidos no exemplo do futebol

# %%
to_clipboard.fillna('-', inplace=True)
to_clipboard
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-12e7daf1d7f8> in <module>()
# ----> 1 to_clipboard.fillna('-', inplace=True)
#       2 to_clipboard
#
# NameError: name 'to_clipboard' is not defined

# %% [markdown]
# ## Operações no Dataframe
# Séries e Dataframes formam o núcleo dos modelos de dados do Pandas em Python. Os conjuntos de dados são lidos primeiro nos Dataframes e, em seguida, várias operações (por exemplo, group by, agregações, etc.) podem ser aplicadas muito facilmente às suas colunas.
#
# ### Grouping
# O método groupby do Pandas parte da estratégia básica de separar-aplicar-combinar (split-apply-combine) em análise de dados. É uma boa representação de como você pensa sobre um problema de dados. Quando ataca-se um problema de análise de dados, geralmente quebra-se ele em pedaços gerenciáveis, realiza várias operações sobre cada um desses pedaços e depois reagrupa todos novamente (este é o essencial da estratégia split- apply-combine).
# ### Merge
# Geralmente em uma análise, precisa-se fazer merge/join de dados que geralmente são armazenados de forma relacional. Como a clausula JOIN no SQL, pandas.merge permite que 2 Dataframes possam ser agrupados por meio de uma ou mais chaves. A função provê uma série de parâmetros (on, left_on, right_on, left_index, right_index) permitindo que você possa especificar sobre quais colunas ou índices deseja-se realizar o join.

# %% [markdown]
# ### Grouping

# %%
from IPython.display import Image
Image('group.png', width = 400)

# %%
import pydataset
df = pydataset.data('titanic')
df.head()
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes
# 3  1st class  adults  man      yes
# 4  1st class  adults  man      yes
# 5  1st class  adults  man      yes

# %%
titanic.describe()
# Out:
#             class     age   sex survived
# count        1316    1316  1316     1316
# unique          3       2     2        2
# top     3rd class  adults   man       no
# freq          706    1207   869      817

# %%
df.groupby('class')['survived'].value_counts().plot(kind='bar', color='r')

# %% [markdown]
# ### Merge

# %%
import pandas as pd
from db import DemoDB

# %%
database = DemoDB()
# Out:
# Indexing schema. This will take a second...finished!

# %%
database.tables
# Out:
# Refreshing schema. Please wait...done!
# +--------+---------------+----------------------------------------------------------------------------------+
# | Schema | Table         | Columns                                                                          |
# +--------+---------------+----------------------------------------------------------------------------------+
# | public | Album         | AlbumId, Title, ArtistId                                                         |
# | public | Artist        | ArtistId, Name                                                                   |
# | public | Customer      | CustomerId, FirstName, LastName, Company, Address, City, State, Country, PostalC |
# |        |               | ode, Phone, Fax, Email, SupportRepId                                             |
# | public | Employee      | EmployeeId, LastName, FirstName, Title, ReportsTo, BirthDate, HireDate, Address, |
# ...

# %%
album = database.tables.Album.all()

# %%
album.head()
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
artist = database.tables.Artist.all()

# %%
artist.head()
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
album_artist = pd.merge(artist, album)

# %%
album_artist.head()
# Out:
#    ArtistId       Name  AlbumId                                  Title
# 0         1      AC/DC        1  For Those About To Rock We Salute You
# 1         1      AC/DC        4                      Let There Be Rock
# 2         2     Accept        2                      Balls to the Wall
# 3         2     Accept        3                      Restless and Wild
# 4         3  Aerosmith        5                               Big Ones

# %%
album_artist = pd.merge(artist, album, on='ArtistId')

# %%
album_artist.head()
# Out:
#    ArtistId       Name  AlbumId                                  Title
# 0         1      AC/DC        1  For Those About To Rock We Salute You
# 1         1      AC/DC        4                      Let There Be Rock
# 2         2     Accept        2                      Balls to the Wall
# 3         2     Accept        3                      Restless and Wild
# 4         3  Aerosmith        5                               Big Ones

# %%
album.rename(columns={'ArtistId': 'Artist_Id'}, inplace=True)

# %%
album.head()
# Out:
#    AlbumId                                  Title  Artist_Id
# 0        1  For Those About To Rock We Salute You          1
# 1        2                      Balls to the Wall          2
# 2        3                      Restless and Wild          2
# 3        4                      Let There Be Rock          1
# 4        5                               Big Ones          3

# %%
album_artist = pd.merge(album, artist, left_on='Artist_Id', right_on='ArtistId')

# %%
album_artist.head()
# Out:
#    AlbumId                                  Title  Artist_Id  ArtistId  \
# 0        1  For Those About To Rock We Salute You          1         1
# 1        4                      Let There Be Rock          1         1
# 2        2                      Balls to the Wall          2         2
# 3        3                      Restless and Wild          2         2
# 4        5                               Big Ones          3         3
#
#         Name
# 0      AC/DC
# 1      AC/DC
# 2     Accept
# 3     Accept
# 4  Aerosmith

# %%
pd.merge(album, artist, left_on='Artist_Id', right_on='ArtistId').drop('Artist_Id', axis=1)
# Out:
#      AlbumId  \
# 0          1
# 1          4
# 2          2
# 3          3
# 4          5
# 5          6
# 6          7
# 7          8
# 8         34
# 9          9
# 10        10
# 11        11
# 12       271
# 13        12
# 14        13
# 15        14
# 16        15
# 17        16
# 18        17
# 19        18
# 20        19
# 21        20
# 22        21
# 23        22
# 24        23
# 25        24
# 26        25
# 27        26
# 28        27
# 29        28
# 30        29
# 31        32
# 32        45
# 33        53
# 34        30
# 35        44
# 36       127
# 37       128
# 38       129
# 39       130
# 40       131
# 41       132
# 42       133
# 43       134
# 44       135
# 45       136
# 46       137
# 47       138
# 48        31
# 49        33
# 50        35
# 51       148
# 52       149
# 53       150
# 54       151
# 55       152
# 56       153
# 57       154
# 58       155
# 59       156
# 60        36
# 61       185
# 62       186
# 63        37
# 64       126
# ...

# %%
alunos1 = pd.DataFrame(
    {
        'nome': ['Maria', 'Sofia'],
        'nota': [8, 9],
    }
)
alunos2 = pd.DataFrame(
    {
        'nome': ['João', 'Pedro', 'Maria'],
        'cod': [1, 2, 3],
    }
)

# %%
alunos_total = pd.merge(alunos1, alunos2, on='nome')

# %%
alunos_total
# Out:
#     nome  nota  cod
# 0  Maria     8    3

# %%
pd.merge(alunos1, alunos2, how='outer')
# Out:
#     nome  nota  cod
# 0  Maria   8.0  3.0
# 1  Sofia   9.0  NaN
# 2   João   NaN  1.0
# 3  Pedro   NaN  2.0

# %%
pd.merge(alunos1, alunos2, how='inner')
# Out:
#     nome  nota  cod
# 0  Maria     8    3

# %%
pd.merge(alunos1, alunos2, how='left')
# Out:
#     nome  nota  cod
# 0  Maria     8  3.0
# 1  Sofia     9  NaN

# %%
pd.merge(alunos1, alunos2, how='right')
# Out:
#     nome  nota  cod
# 0  Maria   8.0    3
# 1   João   NaN    1
# 2  Pedro   NaN    2

# %% [markdown]
# ## Ranking

# %%
import pandas as pd
data = {'Country': ['Belgium', 'India', 'Brazil'], 
        'Capital': ['Brussels', 'New Delhi', 'Brasília'], 
        'Population': [11190846, 303171035, 207847528]}

df = pd.DataFrame(data,columns=['Country', 'Capital', 'Population'])
df
# Out:
#    Country    Capital  Population
# 0  Belgium   Brussels    11190846
# 1    India  New Delhi   303171035
# 2   Brazil   Brasília   207847528

# %%
df['Rank'] = df['Population'].rank(ascending=0)
df
# Out:
#    Country    Capital  Population  Rank
# 0  Belgium   Brussels    11190846   3.0
# 1    India  New Delhi   303171035   1.0
# 2   Brazil   Brasília   207847528   2.0

# %%
df.sort_values(by='Rank',inplace=True)

# %%
df
# Out:
#    Country    Capital  Population  Rank
# 1    India  New Delhi   303171035   1.0
# 2   Brazil   Brasília   207847528   2.0
# 0  Belgium   Brussels    11190846   3.0
