# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplleaflet
import seaborn
# %matplotlib inline

# %%
df = pd.read_csv('copacabana_lat_lng.csv')

# %%
df['Valor Total'] = df['AreaConstruida'] * df['VAL_UNIT']

# %%
df.columns
# Out:
# Index(['Posicao', 'Quartos', 'Vagas', 'DistIpanema', 'DistPraia', 'DistFavela',
#        'RendaMedia', 'RendaMovel', 'RendaMovelRua', 'Vu2009', 'Mes', 'Idade',
#        'Tipologia', 'AreaConstruida', 'VAL_UNIT', 'X', 'Y', 'lat', 'lng',
#        'Valor Total'],
#       dtype='object')

# %%
len(df)
# Out:
# 1675

# %%
df['Valor_Total'] = df['VAL_UNIT']* df['AreaConstruida']

# %%
plt.scatter(df['lng'],df['lat'], c='blue')
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>
